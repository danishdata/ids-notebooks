# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Data.csv", encoding = "latin-1")

# %%
data.head()
# Out:
#      TOWN   TOWN_DESC  LOCALITY  LOCALITY_DESC  SLOCALITY  SLOCALITY_DESC  \
# 0  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 1  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 2  T00027      SADDAR         2    BOHRI BAZAR          3      PRESS CLUB
# 3  T00009     SOCIETY         1    BAHADURABAD          1   CHOTTI MARKET
# 4  T00009     SOCIETY         1    BAHADURABAD          3      SHARIFABAD
#
#           POP_CODE                                  POP_NAME  SECTION  \
# 0  T00026001004014                           AL MACCA BAKERY        1
# 1  T00026001004129                            MUSHTAQ BAKERY        1
# 2  T00027002003092  ABBAS BROTHERS BAKERY & CONFECTIONERY (S        9
# 3  T00009001001010                           FAREED'S BAKERY       16
# 4  T00009001003015                             CRESENT NIMCO       16
#
#      SECTION_DESC   ...     AREATYPE SHOPPER_TYPE    OWNER_NAME  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355178 entries, 0 to 355177
# Data columns (total 37 columns):
# TOWN               355178 non-null object
# TOWN_DESC          355178 non-null object
# LOCALITY           355178 non-null int64
# LOCALITY_DESC      355178 non-null object
# SLOCALITY          355178 non-null int64
# SLOCALITY_DESC     355178 non-null object
# POP_CODE           355178 non-null object
# POP_NAME           355178 non-null object
# SECTION            355178 non-null int64
# SECTION_DESC       355178 non-null object
# POS_TYPE_CODE      355178 non-null int64
# POS_TYPE           355178 non-null object
# DOC_DATE           355178 non-null object
# DOC_NO             355178 non-null int64
# ORDER_STATUS       355178 non-null int64
# PJP                355178 non-null int64
# REF_PJP            355177 non-null float64
# DSR                355178 non-null int64
# REF_DSR            355177 non-null float64
# HHT_SRNO           354757 non-null float64
# ...

# %%
data.describe()
# Out:
#             LOCALITY      SLOCALITY        SECTION  POS_TYPE_CODE  \
# count  355178.000000  355178.000000  355178.000000  355178.000000
# mean        2.869820       2.115193      25.587900       5.513168
# std         1.442698       1.157632      16.175905       3.328402
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       1.000000      10.000000       4.000000
# 50%         3.000000       2.000000      30.000000       4.000000
# 75%         4.000000       3.000000      41.000000       7.000000
# max         8.000000       7.000000      54.000000      20.000000
#
#              DOC_NO   ORDER_STATUS            PJP        REF_PJP  \
# count  3.551780e+05  355178.000000  355178.000000  355177.000000
# mean   1.516422e+11       0.442381       9.341829    1125.131388
# std    1.366982e+10       0.496670       9.023358     323.627075
# min    1.000091e+06       0.000000       1.000000       1.000000
# ...

# %%
print(data.shape)
# Out:
# (355178, 37)

# %%
data.count()
# Out:
# TOWN               355178
# TOWN_DESC          355178
# LOCALITY           355178
# LOCALITY_DESC      355178
# SLOCALITY          355178
# SLOCALITY_DESC     355178
# POP_CODE           355178
# POP_NAME           355178
# SECTION            355178
# SECTION_DESC       355178
# POS_TYPE_CODE      355178
# POS_TYPE           355178
# DOC_DATE           355178
# DOC_NO             355178
# ORDER_STATUS       355178
# PJP                355178
# REF_PJP            355177
# DSR                355178
# REF_DSR            355177
# HHT_SRNO           354757
# USER_ENTRY         355178
# PAYMENT_MODE       354664
# MARKET_NAME        355178
# STREET             354951
# COMPANY_RANK       355178
# RANK               355178
# ACTIVE             355178
# AREATYPE           355178
# SHOPPER_TYPE       350022
# OWNER_NAME         355178
# GPS_COORDINATES    304869
# GEOCODE            355178
# RURAL              355178
# SUB_ELEMENT        355178
# CHANNEL            355178
# ...

# %%
data[['GPS_COORDINATES']] = data[['GPS_COORDINATES']].fillna(value = '0.0,0.0')

# %%
pd.set_option('display.max_columns', None)

# %%
data[['STREET']] = data[['STREET']].fillna(value = 'N/A')

# %%
data.head()
# Out:
#      TOWN   TOWN_DESC  LOCALITY  LOCALITY_DESC  SLOCALITY  SLOCALITY_DESC  \
# 0  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 1  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 2  T00027      SADDAR         2    BOHRI BAZAR          3      PRESS CLUB
# 3  T00009     SOCIETY         1    BAHADURABAD          1   CHOTTI MARKET
# 4  T00009     SOCIETY         1    BAHADURABAD          3      SHARIFABAD
#
#           POP_CODE                                  POP_NAME  SECTION  \
# 0  T00026001004014                           AL MACCA BAKERY        1
# 1  T00026001004129                            MUSHTAQ BAKERY        1
# 2  T00027002003092  ABBAS BROTHERS BAKERY & CONFECTIONERY (S        9
# 3  T00009001001010                           FAREED'S BAKERY       16
# 4  T00009001003015                             CRESENT NIMCO       16
#
#      SECTION_DESC  POS_TYPE_CODE POS_TYPE                 DOC_DATE  \
# ...

# %%
data[['SHOPPER_TYPE']] = data[['SHOPPER_TYPE']].fillna(value = '01')

# %%
data.head()
# Out:
#      TOWN   TOWN_DESC  LOCALITY  LOCALITY_DESC  SLOCALITY  SLOCALITY_DESC  \
# 0  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 1  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 2  T00027      SADDAR         2    BOHRI BAZAR          3      PRESS CLUB
# 3  T00009     SOCIETY         1    BAHADURABAD          1   CHOTTI MARKET
# 4  T00009     SOCIETY         1    BAHADURABAD          3      SHARIFABAD
#
#           POP_CODE                                  POP_NAME  SECTION  \
# 0  T00026001004014                           AL MACCA BAKERY        1
# 1  T00026001004129                            MUSHTAQ BAKERY        1
# 2  T00027002003092  ABBAS BROTHERS BAKERY & CONFECTIONERY (S        9
# 3  T00009001001010                           FAREED'S BAKERY       16
# 4  T00009001003015                             CRESENT NIMCO       16
#
#      SECTION_DESC  POS_TYPE_CODE POS_TYPE                 DOC_DATE  \
# ...

# %%
data.count()
# Out:
# TOWN               355178
# TOWN_DESC          355178
# LOCALITY           355178
# LOCALITY_DESC      355178
# SLOCALITY          355178
# SLOCALITY_DESC     355178
# POP_CODE           355178
# POP_NAME           355178
# SECTION            355178
# SECTION_DESC       355178
# POS_TYPE_CODE      355178
# POS_TYPE           355178
# DOC_DATE           355178
# DOC_NO             355178
# ORDER_STATUS       355178
# PJP                355178
# REF_PJP            355177
# DSR                355178
# REF_DSR            355177
# HHT_SRNO           354757
# USER_ENTRY         355178
# PAYMENT_MODE       354664
# MARKET_NAME        355178
# STREET             355178
# COMPANY_RANK       355178
# RANK               355178
# ACTIVE             355178
# AREATYPE           355178
# SHOPPER_TYPE       355178
# OWNER_NAME         355178
# GPS_COORDINATES    355178
# GEOCODE            355178
# RURAL              355178
# SUB_ELEMENT        355178
# CHANNEL            355178
# ...

# %%
data[['REF_PJP']] = data[['REF_PJP']].fillna(value = '1007')

# %%
data.columns
# Out:
# Index(['TOWN', 'TOWN_DESC', 'LOCALITY', 'LOCALITY_DESC', 'SLOCALITY',
#        'SLOCALITY_DESC', 'POP_CODE', 'POP_NAME', 'SECTION', 'SECTION_DESC',
#        'POS_TYPE_CODE', 'POS_TYPE', 'DOC_DATE', 'DOC_NO', 'ORDER_STATUS',
#        'PJP', 'REF_PJP', 'DSR', 'REF_DSR', 'HHT_SRNO', 'USER_ENTRY',
#        'PAYMENT_MODE', 'MARKET_NAME', 'STREET', 'COMPANY_RANK', 'RANK',
#        'ACTIVE', 'AREATYPE', 'SHOPPER_TYPE', 'OWNER_NAME', 'GPS_COORDINATES',
#        'GEOCODE', 'RURAL', 'SUB_ELEMENT', 'CHANNEL', 'SUB_CHANNEL', 'ELEMENT'],
#       dtype='object')

# %%
data[['HHT_SRNO']] = data[['HHT_SRNO']].fillna(value = '0')

# %%
data.count()
# Out:
# TOWN               355178
# TOWN_DESC          355178
# LOCALITY           355178
# LOCALITY_DESC      355178
# SLOCALITY          355178
# SLOCALITY_DESC     355178
# POP_CODE           355178
# POP_NAME           355178
# SECTION            355178
# SECTION_DESC       355178
# POS_TYPE_CODE      355178
# POS_TYPE           355178
# DOC_DATE           355178
# DOC_NO             355178
# ORDER_STATUS       355178
# PJP                355178
# REF_PJP            355178
# DSR                355178
# REF_DSR            355177
# HHT_SRNO           355178
# USER_ENTRY         355178
# PAYMENT_MODE       354664
# MARKET_NAME        355178
# STREET             355178
# COMPANY_RANK       355178
# RANK               355178
# ACTIVE             355178
# AREATYPE           355178
# SHOPPER_TYPE       355178
# OWNER_NAME         355178
# GPS_COORDINATES    355178
# GEOCODE            355178
# RURAL              355178
# SUB_ELEMENT        355178
# CHANNEL            355178
# ...

# %%
data[['REF_DSR']] = data[['REF_DSR']].fillna(value = '107')

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#      TOWN   TOWN_DESC  LOCALITY  LOCALITY_DESC  SLOCALITY  SLOCALITY_DESC  \
# 0  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 1  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 2  T00027      SADDAR         2    BOHRI BAZAR          3      PRESS CLUB
# 3  T00009     SOCIETY         1    BAHADURABAD          1   CHOTTI MARKET
# 4  T00009     SOCIETY         1    BAHADURABAD          3      SHARIFABAD
#
#           POP_CODE                                  POP_NAME  SECTION  \
# 0  T00026001004014                           AL MACCA BAKERY        1
# 1  T00026001004129                            MUSHTAQ BAKERY        1
# 2  T00027002003092  ABBAS BROTHERS BAKERY & CONFECTIONERY (S        9
# 3  T00009001001010                           FAREED'S BAKERY       16
# 4  T00009001003015                             CRESENT NIMCO       16
#
#      SECTION_DESC  POS_TYPE_CODE POS_TYPE                 DOC_DATE  \
# ...

# %%
data.count()
# Out:
# TOWN               355178
# TOWN_DESC          355178
# LOCALITY           355178
# LOCALITY_DESC      355178
# SLOCALITY          355178
# SLOCALITY_DESC     355178
# POP_CODE           355178
# POP_NAME           355178
# SECTION            355178
# SECTION_DESC       355178
# POS_TYPE_CODE      355178
# POS_TYPE           355178
# DOC_DATE           355178
# DOC_NO             355178
# ORDER_STATUS       355178
# PJP                355178
# REF_PJP            355178
# DSR                355178
# REF_DSR            355178
# HHT_SRNO           355178
# USER_ENTRY         355178
# PAYMENT_MODE       354664
# MARKET_NAME        355178
# STREET             355178
# COMPANY_RANK       355178
# RANK               355178
# ACTIVE             355178
# AREATYPE           355178
# SHOPPER_TYPE       355178
# OWNER_NAME         355178
# GPS_COORDINATES    355178
# GEOCODE            355178
# RURAL              355178
# SUB_ELEMENT        355178
# CHANNEL            355178
# ...

# %%
data['STREET'] = data['STREET'].replace(['-'], 'N/A')

# %%
data['MARKET_NAME'] = data['MARKET_NAME'].replace(['-'], 'N/A')

# %%
data.head()
# Out:
#      TOWN   TOWN_DESC  LOCALITY  LOCALITY_DESC  SLOCALITY  SLOCALITY_DESC  \
# 0  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 1  T00026  PIB COLONY         1  JAMSHEED ROAD          4  MARTIN QUARTER
# 2  T00027      SADDAR         2    BOHRI BAZAR          3      PRESS CLUB
# 3  T00009     SOCIETY         1    BAHADURABAD          1   CHOTTI MARKET
# 4  T00009     SOCIETY         1    BAHADURABAD          3      SHARIFABAD
#
#           POP_CODE                                  POP_NAME  SECTION  \
# 0  T00026001004014                           AL MACCA BAKERY        1
# 1  T00026001004129                            MUSHTAQ BAKERY        1
# 2  T00027002003092  ABBAS BROTHERS BAKERY & CONFECTIONERY (S        9
# 3  T00009001001010                           FAREED'S BAKERY       16
# 4  T00009001003015                             CRESENT NIMCO       16
#
#      SECTION_DESC  POS_TYPE_CODE POS_TYPE                 DOC_DATE  \
# ...

# %%
data.PAYMENT_MODE.value_counts(dropna=False).head()
# Out:
#  1.0    336586
#  2.0     18078
# NaN        514
# Name: PAYMENT_MODE, dtype: int64

# %%
data.SHOPPER_TYPE.value_counts(dropna=False).head()
# Out:
# RG    241177
# 01    113638
# L1       363
# Name: SHOPPER_TYPE, dtype: int64

# %%
data.describe()
# Out:
#             LOCALITY      SLOCALITY        SECTION  POS_TYPE_CODE  \
# count  355178.000000  355178.000000  355178.000000  355178.000000
# mean        2.869820       2.115193      25.587900       5.513168
# std         1.442698       1.157632      16.175905       3.328402
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       1.000000      10.000000       4.000000
# 50%         3.000000       2.000000      30.000000       4.000000
# 75%         4.000000       3.000000      41.000000       7.000000
# max         8.000000       7.000000      54.000000      20.000000
#
#              DOC_NO   ORDER_STATUS            PJP            DSR  \
# count  3.551780e+05  355178.000000  355178.000000  355178.000000
# mean   1.516422e+11       0.442381       9.341829       9.358080
# std    1.366982e+10       0.496670       9.023358       6.936887
# min    1.000091e+06       0.000000       1.000000       1.000000
# ...

# %%
print (data.dtypes)
# Out:
# TOWN                       object
# TOWN_DESC                  object
# LOCALITY                    int64
# LOCALITY_DESC              object
# SLOCALITY                   int64
# SLOCALITY_DESC             object
# POP_CODE                   object
# POP_NAME                   object
# SECTION                     int64
# SECTION_DESC               object
# POS_TYPE_CODE               int64
# POS_TYPE                   object
# DOC_DATE           datetime64[ns]
# DOC_NO                      int64
# ORDER_STATUS             category
# PJP                         int64
# REF_PJP                     int64
# DSR                         int64
# REF_DSR                     int64
# HHT_SRNO                    int64
# USER_ENTRY                 object
# PAYMENT_MODE             category
# MARKET_NAME                object
# STREET                     object
# COMPANY_RANK                int64
# RANK                        int64
# ACTIVE                   category
# ...

# %%
data.REF_PJP = data.REF_PJP.astype('int64')

# %%
data.HHT_SRNO = data.HHT_SRNO.astype('int64')

# %%
data.REF_DSR = data.REF_DSR.astype('int64')

# %%
data.PAYMENT_MODE = data.PAYMENT_MODE.astype('category')

# %%
data.AREATYPE = data.AREATYPE.astype('category')

# %%
data.RURAL = data.RURAL.astype('category')

# %%
data.ELEMENT = data.ELEMENT.astype('category')

# %%
data.SUB_CHANNEL = data.SUB_CHANNEL.astype('category')

# %%
data.CHANNEL = data.CHANNEL.astype('category')

# %%
data.SUB_ELEMENT = data.SUB_ELEMENT.astype('category')

# %%
data.SHOPPER_TYPE = data.SHOPPER_TYPE.astype('category')

# %%
data.ACTIVE = data.ACTIVE.astype('category')

# %%
data.ORDER_STATUS = data.ORDER_STATUS.astype('category')

# %%
data.DOC_DATE = pd.to_datetime(data.DOC_DATE)

# %%
data.PAYMENT_MODE = data.PAYMENT_MODE.fillna(data.PAYMENT_MODE.value_counts().index[0])

# %%
data.PAYMENT_MODE.value_counts(dropna=False).head()
# Out:
# 1.0    337100
# 2.0     18078
# Name: PAYMENT_MODE, dtype: int64
